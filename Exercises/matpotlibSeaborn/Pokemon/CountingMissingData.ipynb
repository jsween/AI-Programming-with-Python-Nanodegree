# %%
import numpy as np
import pandas as pd

df = pd.read_csv('sales-data.csv')

# %%
# df.isna() same as below
df.isnull()
# Out:
#       Store   Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0     False  False        False       False       True       True       True
# 1     False  False        False       False       True       True       True
# 2     False  False        False       False       True       True       True
# 3     False  False        False       False       True       True       True
# 4     False  False        False       False       True       True       True
# ...     ...    ...          ...         ...        ...        ...        ...
# 8185  False  False        False       False      False      False      False
# 8186  False  False        False       False      False      False      False
# 8187  False  False        False       False      False      False      False
# 8188  False  False        False       False      False      False      False
# 8189  False  False        False       False      False      False      False
#
# ...

# %%
df.shape
# Out:
# (8190, 12)

# %%
df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
# drop columns without NaN values
na_counts = df.drop(['Date', 'Temperature', 'Fuel_Price'], axis=1).isna().sum()
print(na_counts)
# Out:
# Store              0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
na_counts_df = na_counts.reset_index()
na_counts_df.columns = ['categories', 'frequency']
na_counts_df
# Out:
#      categories  frequency
# 0         Store          0
# 1     MarkDown1       4158
# 2     MarkDown2       5269
# 3     MarkDown3       4577
# 4     MarkDown4       4726
# 5     MarkDown5       4140
# 6           CPI        585
# 7  Unemployment        585
# 8     IsHoliday          0

# %%
# The first argument to the function below contains the x-values (column names), the second argument the y-values (our counts).
# Refer to the syntax and more example here - https://seaborn.pydata.org/generated/seaborn.barplot.html
sb.barplot(data=na_counts_df, x='categories', y='frequency')#,x=na_counts, y=na_counts)

# get the current tick locations and labels
plt.xticks(rotation=90)

print(na_counts_df.iloc[1])
# Logic to print value on each bar
for i in range (na_counts_df.shape[0]):
    count = na_counts_df.iloc[i][1]
    # Refer here for details of the text() - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.text.html
    plt.text(i, count+300, count, ha = 'center', va='top')
# Out:
# categories    MarkDown1
# frequency          4158
# Name: 1, dtype: object
